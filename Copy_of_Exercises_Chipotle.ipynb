# %% [markdown]
# <a href="https://colab.research.google.com/github/vick998/Banzae-py/blob/main/Copy_of_Exercises_Chipotle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
#import requests
#import io

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo=pd.read_csv(url, sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
# 126

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1

len(chipo.index.array)
# Out:
# 4622

# %%
chipo.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
# Solution 2

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(chipo.columns)
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
for i in chipo.columns:
  print(i)
# Out:
# order_id
# quantity
# item_name
# choice_description
# item_price

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
chipo2 = chipo.groupby('item_name')
#chipo2.head(1).index[0][0]
chipo2.describe()
# Out:
#                                       order_id                           \
#                                          count         mean         std
# item_name
# 6 Pack Soft Drink                         54.0   968.925926  537.830402
# Barbacoa Bowl                             66.0   817.757576  538.969246
# Barbacoa Burrito                          91.0   821.076923  555.170029
# Barbacoa Crispy Tacos                     11.0   510.272727  421.439934
# Barbacoa Salad Bowl                       10.0   970.800000  450.374363
# Barbacoa Soft Tacos                       25.0   749.000000  465.655094
# Bottled Water                            162.0  1086.074074  488.464390
# Bowl                                       2.0   236.000000   60.811183
# Burrito                                    6.0   258.333333   49.078169
# Canned Soda                              104.0   734.576923  534.727400
# Canned Soft Drink                        301.0  1012.468439  544.687106
# ...

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
chipo0.values
itnum = 0
for i in range(len(chipo0.values)):
  if chipo0.values[i][2]==chipo2.head(1).index[0][0]:
    itnum+=int(chipo0.values[i][1])
itnum
# Out:
# 506

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
chipo3 = chipo0.loc[:,'choice_description'].value_counts()
if chipo3.head(1).index[0][0] == 'NULL':
  print(chipo3.index[1][0])
#chipo3
# Out:
# [Diet Coke]
# (choice_description,)
# NULL                                     1246
# [Diet Coke]                               134
# [Coke]                                    123
# [Sprite]                                   77
# [Lemonade]                                 33
# [Coca Cola]                                26
# [Nestea]                                   20
# [Dr. Pepper]                               18
# [Mountain Dew]                             15
# [Diet Dr. Pepper]                          13
# [Fresh Tomato Salsa]                       11
# [Roasted Chili Corn Salsa]                 10
# [Tomatillo Red Chili Salsa]                 9
# [Clementine]                                8
# [Blackberry]                                8
# [Peach Orange]                              8
# [Pineapple Orange Banana]                   8
# [Tomatillo Green Chili Salsa]               6
# [Apple]                                     6
# [Pomegranate Cherry]                        5
# ...

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
itsum = 0
for i in chipo0['quantity'].values:
  itsum+=int(i)
itsum
# Out:
# 2010

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %% [markdown]
# #### Step 13.c. Check the item price type

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1

# %%
# Solution 2

# %% [markdown]
# ### Step 17. How many different items are sold?
