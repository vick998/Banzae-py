# %% [markdown]
# <a href="https://colab.research.google.com/github/vick998/Banzae-py/blob/main/Cheatsheet2_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'a':[4,5,6],'b':[7,8,9],'c':[10,11,12]},index=[1,2,3])
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df1 = pd.DataFrame([[4,7,10],[5,8,11],[6,9,12]],index=[1,2,3],columns=['a','b','c'])
df1
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
index = pd.MultiIndex.from_tuples([('x','d',1),('x','d',2),('x','e',2)],names=['s','n','v'])
df2 = pd.DataFrame({'a':[4,5,6],'b':[7,8,9],'c':[10,11,12]},index=index)
df2
# Out:
#        a  b   c
# s n v
# x d 1  4  7  10
#     2  5  8  11
#   e 2  6  9  12

# %%
df3 = pd.DataFrame([[4,7,float('NAN')],[5,float('NAN'),float('NAN')],[float('NAN'),float('NAN'),float('NAN')]],index=[1,2,3],columns=['A','B','C'])
df3
# Out:
#      A    B   C
# 1  4.0  7.0 NaN
# 2  5.0  NaN NaN
# 3  NaN  NaN NaN

# %%
for i in range(3):
  for k in range(3):
    df.iloc[i,k]*=100
df
df0 = (pd.melt(df).rename(columns={'variable':'var','value':'val'}).query('val >= 200'))
df0
# Out:
#   var   val
# 0   a   400
# 1   a   500
# 2   a   600
# 3   b   700
# 4   b   800
# 5   b   900
# 6   c  1000
# 7   c  1100
# 8   c  1200

# %%
df.melt()
# Out:
#   variable  value
# 0        a      4
# 1        a      5
# 2        a      6
# 3        b      7
# 4        b      8
# 5        b      9
# 6        c     10
# 7        c     11
# 8        c     12

# %%
df0.pivot(columns='var',values='val')
# Out:
# var      a      b       c
# 0    400.0    NaN     NaN
# 1    500.0    NaN     NaN
# 2    600.0    NaN     NaN
# 3      NaN  700.0     NaN
# 4      NaN  800.0     NaN
# 5      NaN  900.0     NaN
# 6      NaN    NaN  1000.0
# 7      NaN    NaN  1100.0
# 8      NaN    NaN  1200.0

# %%
df11 = pd.concat([df1,df])
df11
# Out:
#      a    b     c
# 1    4    7    10
# 2    5    8    11
# 3    6    9    12
# 1  400  700  1000
# 2  500  800  1100
# 3  600  900  1200

# %%
pd.concat([df1,df],axis=1)
# Out:
#    a  b   c    a    b     c
# 1  4  7  10  400  700  1000
# 2  5  8  11  500  800  1100
# 3  6  9  12  600  900  1200

# %%
df11.sort_values(by=['a'],ascending=False)
# Out:
#      a    b     c
# 3  600  900  1200
# 2  500  800  1100
# 1  400  700  1000
# 3    6    9    12
# 2    5    8    11
# 1    4    7    10

# %%
df11.sort_values(by=['a'])
# Out:
#      a    b     c
# 1    4    7    10
# 2    5    8    11
# 3    6    9    12
# 1  400  700  1000
# 2  500  800  1100
# 3  600  900  1200

# %%
df12=df11.rename(columns={'a':'A','b':'B','c':'C'})
df12
# Out:
#      A    B     C
# 1    4    7    10
# 2    5    8    11
# 3    6    9    12
# 1  400  700  1000
# 2  500  800  1100
# 3  600  900  1200

# %%
df11.sort_index()
# Out:
#      a    b     c
# 1    4    7    10
# 1  400  700  1000
# 2    5    8    11
# 2  500  800  1100
# 3    6    9    12
# 3  600  900  1200

# %%
df12=df12.reset_index()
df12
# Out:
#    index    A    B     C
# 0      1    4    7    10
# 1      2    5    8    11
# 2      3    6    9    12
# 3      1  400  700  1000
# 4      2  500  800  1100
# 5      3  600  900  1200

# %%
df12=df12.drop(columns='index')
df12
# Out:
#      A    B     C
# 0    4    7    10
# 1    5    8    11
# 2    6    9    12
# 3  400  700  1000
# 4  500  800  1100
# 5  600  900  1200

# %%
df31=pd.concat([df1,df3],axis=1)
df31
# Out:
#    a  b   c    A    B   C
# 1  4  7  10  4.0  7.0 NaN
# 2  5  8  11  5.0  NaN NaN
# 3  6  9  12  NaN  NaN NaN

# %%
df31[df31.Length>5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-25bdb6c66b88> in <module>()
# ----> 1 df31[df31.Length>5]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Length'

# %%
df13 = pd.concat([df,df1])
df13
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df14 = pd.concat([df,df1],axis=1)
df14
# Out:
#    a  b   c  a  b   c
# 1  4  7  10  4  7  10
# 2  5  8  11  5  8  11
# 3  6  9  12  6  9  12

# %%
df13.drop_duplicates()
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df14.drop_duplicates()
# Out:
#    a  b   c  a  b   c
# 1  4  7  10  4  7  10
# 2  5  8  11  5  8  11
# 3  6  9  12  6  9  12

# %%
df.sample(frac=0.3)
# Out:
#    a  b   c
# 2  5  8  11

# %%
df.sample(2)
# Out:
#    a  b   c
# 1  4  7  10
# 3  6  9  12

# %%
df.iloc[0,0:3]
# Out:
# a     4
# b     7
# c    10
# Name: 1, dtype: int64

# %%
df12.nlargest(5,'A')
# Out:
#      A    B     C
# 5  600  900  1200
# 4  500  800  1100
# 3  400  700  1000
# 2    6    9    12
# 1    5    8    11

# %%
df12.nsmallest(5,'A')
# Out:
#      A    B     C
# 0    4    7    10
# 1    5    8    11
# 2    6    9    12
# 3  400  700  1000
# 4  500  800  1100

# %%
df['a'].isin([5,6])
# Out:
# 1    False
# 2     True
# 3     True
# Name: a, dtype: bool

# %%
df.isin([5])
# Out:
#        a      b      c
# 1  False  False  False
# 2   True  False  False
# 3  False  False  False

# %%
pd.isnull(df)
# Out:
#        a      b      c
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
pd.isnull(df3)
# Out:
#        a      b     c
# 1  False  False  True
# 2  False   True  True
# 3   True   True  True

# %%
pd.notnull(df3b)
# Out:
#        a      b      c
# 1   True   True  False
# 2   True  False  False
# 3  False  False  False

# %%
df.b
# Out:
# 1    7
# 2    8
# 3    9
# Name: b, dtype: int64

# %%
df.filter(regex='^a')
# Out:
#    a
# 1  4
# 2  5
# 3  6

# %%
df[['a','c']]
# Out:
#    a   c
# 1  4  10
# 2  5  11
# 3  6  12

# %%
df14.iloc[:,2:4]
# Out:
#     c  a
# 1  10  4
# 2  11  5
# 3  12  6

# %%
df14.iloc[:,[1,5,3]]
# Out:
#    b   c  a
# 1  7  10  4
# 2  8  11  5
# 3  9  12  6

# %%
df31.loc[:,'a':'A']
# Out:
#    a  b   c    A
# 1  4  7  10  4.0
# 2  5  8  11  5.0
# 3  6  9  12  NaN

# %%
df31.loc[df31.a>5,'c':'B']
# Out:
#     c   A   B
# 3  12 NaN NaN
