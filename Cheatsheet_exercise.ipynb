# %% [markdown]
# <a href="https://colab.research.google.com/github/vick998/Banzae-py/blob/main/Cheatsheet_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dict1 = {'col1':['a','b','c','a','b','c','a','b','c'], 'col2':['R','G','B','B','R','G','G','B','R'], 'col3':[0,1.12,2.23,3.34,4.45,5.56,6.67,7.78,float('NaN')]}
dict2 = {'col1':[0.1,1.13,2.24], 'col2':[3.35,4.46,5.57], 'col3':[6.68,7.79,float('NaN')]}

# %%
df1 = pd.DataFrame(data=dict1)
df2 = pd.DataFrame(data=dict2)

# %%
df1.pivot(columns=['col1','col2'], values='col3')
# Out:
# col1    a     b     c     a     b     c     a     b     c
# col2    R     G     B     B     R     G     G     B     R
# 0     0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN  1.12   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN  2.23   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN  3.34   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN   NaN  4.45   NaN   NaN   NaN   NaN
# 5     NaN   NaN   NaN   NaN   NaN  5.56   NaN   NaN   NaN
# 6     NaN   NaN   NaN   NaN   NaN   NaN  6.67   NaN   NaN
# 7     NaN   NaN   NaN   NaN   NaN   NaN   NaN  7.78   NaN
# 8     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  8.89

# %%
pd.pivot_table(df1,columns=['col1','col2'],values='col3')
# Out:
# col1     a                b                 c
# col2     B     G    R     B     G     R     B     G     R
# col3  3.34  6.67  0.0  7.78  1.12  4.45  2.23  5.56  8.89

# %%
df1piv = df1.pivot(index='col1', columns='col2', values='col3')
df1piv
# Out:
# col2     B     G     R
# col1
# a     3.34  6.67  0.00
# b     7.78  1.12  4.45
# c     2.23  5.56  8.89

# %%
df1piv.stack()
# Out:
# col1  col2
# a     B       3.34
#       G       6.67
#       R       0.00
# b     B       7.78
#       G       1.12
#       R       4.45
# c     B       2.23
#       G       5.56
#       R       8.89
# dtype: float64

# %%
pd.melt(df1,id_vars='col1',value_vars=['col2','col3'],value_name='Observations')
# Out:
#    col1 variable Observations
# 0     a     col2            R
# 1     b     col2            G
# 2     c     col2            B
# 3     a     col2            B
# 4     b     col2            R
# 5     c     col2            G
# 6     a     col2            G
# 7     b     col2            B
# 8     c     col2            R
# 9     a     col3          0.0
# 10    b     col3         1.12
# 11    c     col3         2.23
# 12    a     col3         3.34
# 13    b     col3         4.45
# 14    c     col3         5.56
# 15    a     col3         6.67
# 16    b     col3         7.78
# 17    c     col3         8.89

# %%
df1.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x7f55d1e53e50>

# %%
df1piv
# Out:
# col2     B     G     R
# col1
# a     3.34  6.67  0.00
# b     7.78  1.12  4.45
# c     2.23  5.56  8.89

# %%
df1piv.loc[:,(df1piv>6).all()]
# Out:
# Empty DataFrame
# Columns: []
# Index: [a, b, c]

# %%
df1piv.loc[(df1piv>0).any(),:]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-104-339de1e7aee6> in <module>()
# ----> 1 df1piv.loc[(df1piv>0).any(),:]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
df2.loc[1:,df2.notnull().all()]
# Out:
#    col1  col2
# 1  1.13  4.46
# 2  2.24  5.57

# %%
df1[df1.col3.isin(df2.col3)]
# Out:
#   col1 col2  col3
# 8    c    R   NaN

# %%
df1.filter(items=["col1"])
# Out:
#   col1
# 0    a
# 1    b
# 2    c
# 3    a
# 4    b
# 5    c
# 6    a
# 7    b
# 8    c

# %%
df1.select(lambda x: not x==0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-84e62bf0c597> in <module>()
# ----> 1 df1.loc[:,lambda df1: df1==0]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
df1.where(df1>3,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-156-6145f9461518> in <module>()
# ----> 1 df1.where(df1>3,10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    6852
#    6853         # See GH#4537 for discussion of scalar op behavior
# ...

# %%
df1.set_index('col1')
# Out:
#      col2  col3
# col1
# a       R  0.00
# b       G  1.12
# c       B  2.23
# a       B  3.34
# b       R  4.45
# c       G  5.56
# a       G  6.67
# b       B  7.78
# c       R   NaN

# %%
df3 = df1.reset_index()
df3
# Out:
#    index col1 col2  col3
# 0      0    a    R  0.00
# 1      1    b    G  1.12
# 2      2    c    B  2.23
# 3      3    a    B  3.34
# 4      4    b    R  4.45
# 5      5    c    G  5.56
# 6      6    a    G  6.67
# 7      7    b    B  7.78
# 8      8    c    R   NaN

# %%
df31 = df3.set_index('col1')
df31
# Out:
#       index col2  col3
# col1
# a         0    R  0.00
# b         1    G  1.12
# c         2    B  2.23
# a         3    B  3.34
# b         4    R  4.45
# c         5    G  5.56
# a         6    G  6.67
# b         7    B  7.78
# c         8    R   NaN

# %%
df31 = df31.rename(index={'a':'x','b':'y','c':'z'}, columns={'index':'col0','col2':'col1','col3':'col2'})
df31
# Out:
#       col0  col1  col1
# col1
# x        0     R  0.00
# y        1     G  1.12
# z        2     B  2.23
# x        3     B  3.34
# y        4     R  4.45
# z        5     G  5.56
# x        6     G  6.67
# y        7     B  7.78
# z        8     R   NaN

# %%
df32=df1.reindex([1,3,2,4,6,5,8,7,9])
df32
# Out:
#   col1 col2  col3
# 1    b    G  1.12
# 3    a    B  3.34
# 2    c    B  2.23
# 4    b    R  4.45
# 6    a    G  6.67
# 5    c    G  5.56
# 8    c    R   NaN
# 7    b    B  7.78
# 9  NaN  NaN   NaN

# %%
arrays = [np.array([1,2,3]),np.array([5,4,3])]
arrays
df5 = pd.DataFrame(np.random.rand(3,2),index=arrays)
df5
tuples = list(zip(*arrays))
tuples
index=pd.MultiIndex.from_tuples(tuples, names=['first','second'])
index
df6=pd.DataFrame(np.random.rand(3,2),index=index)
df6
# Out:
#                      0         1
# first second
# 1     5       0.902649  0.696961
# 2     4       0.734134  0.957047
# 3     3       0.859970  0.305333

# %%
df1['col2'].unique()
df1['col3'].duplicated()
df1.index.duplicated()
df1.drop_duplicates('col2',keep="last")
# Out:
#   col1 col2  col3
# 6    a    G  6.67
# 7    b    B  7.78
# 8    c    R   NaN

# %%
df1.groupby(by='col2').sum()
df1.groupby(by='col2').mean()
df1.groupby(level=0).mean()
df1.groupby(level=0).agg({'col1':lambda x:sum(x)/len(x),'col2':np.sum})
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py:436: FutureWarning: Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#   key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-251-86b4a7e24f70> in <module>()
#       2 df1.groupby(by='col2').mean()
#       3 df1.groupby(level=0).mean()
# ----> 4 df1.groupby(level=0).agg({'col1':lambda x:sum(x)/len(x),'col2':np.sum})
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     977
#     978         op = GroupByApply(self, func, args, kwargs)
# --> 979         result = op.agg()
# ...

# %%
customSum = lambda x: (x+x%2)
df1.groupby(level=0).transform(customSum)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.transform is deprecated. In a future version, a TypeError will be raised. Before calling .transform, select only columns which should be valid for the transforming function.
#    col3
# 0  0.00
# 1  2.24
# 2  2.46
# 3  4.68
# 4  4.90
# 5  7.12
# 6  7.34
# 7  9.56
# 8   NaN

# %%
df2.dropna()
# Out:
#    col1  col2  col3
# 0  0.10  3.35  6.68
# 1  1.13  4.46  7.79

# %%
df2.fillna(df2.mean())
# Out:
#    col1  col2   col3
# 0  0.10  3.35  6.680
# 1  1.13  4.46  7.790
# 2  2.24  5.57  7.235

# %%
df2.replace(2.24,15.5)
# Out:
#     col1  col2  col3
# 0   0.10  3.35  6.68
# 1   1.13  4.46  7.79
# 2  15.50  5.57   NaN

# %%
df1s = df1.head(3)
df1s
df2
# Out:
#    col1  col2  col3
# 0  0.10  3.35  6.68
# 1  1.13  4.46  7.79
# 2  2.24  5.57   NaN

# %%
dict3 = {'X1':['a','b','c'],'X2':[11.432,1.303,99.906]}
dict4 = {'X1':['a','b','d'],'X3':[20.784,float("NaN"),20.784]}
x1=pd.DataFrame(data=dict3)
x2=pd.DataFrame(data=dict4)

pd.merge(x1,x2,how='left',on='X1')
# Out:
#   X1      X2      X3
# 0  a  11.432  20.784
# 1  b   1.303     NaN
# 2  c  99.906     NaN

# %%
x1.join(x2, how='right')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-282-0e79b489bcd0> in <module>()
# ----> 1 x1.join(x2, how='right')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9098         """
#    9099         return self._join_compat(
# -> 9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#    9102
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9136                 right_index=True,
#    9137                 suffixes=(lsuffix, rsuffix),
# -> 9138                 sort=sort,
#    9139             )
#    9140         else:
#
# ...

# %%
x1.append(x2)
# Out:
#   X1      X2      X3
# 0  a  11.432     NaN
# 1  b   1.303     NaN
# 2  c  99.906     NaN
# 0  a     NaN  20.784
# 1  b     NaN     NaN
# 2  d     NaN  20.784

# %%
pd.concat([x1,x2],axis=1,join='inner')
# Out:
#   X1      X2 X1      X3
# 0  a  11.432  a  20.784
# 1  b   1.303  b     NaN
# 2  c  99.906  d  20.784

# %%
pd.concat([x1,x2],axis=1,keys["One","Two"])
# Out:
#   File "<ipython-input-285-41a0836df648>", line 1
#     pd.concat([x1,x2],axis=1,keys["One","Two"])
#                             ^
# SyntaxError: positional argument follows keyword argument
